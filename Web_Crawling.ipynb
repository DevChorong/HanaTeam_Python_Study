# %% [markdown]
# <a href="https://colab.research.google.com/github/DevChorong/HanaTeam_Python_Study/blob/main/Web_Crawling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests

# %%
from bs4 import BeautifulSoup # 데이터 정리용 서적(라이브러리)
import requests # HTML 소스코드 (웹페이지 소스코드) 호출용 라이브러리

# requests 라는 기술을 가진 책을 컴퓨터가 읽을 수 있도록 가져와 주세요
# import = 수입하다.
# "이름들" = 라이브러리.

# %%
# 부가적인 책들
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 네이버 영화 평점 사이트 연결 요청 ('Real Steel')

URL = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.naver?code=76460&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1'
connect = requests.get(URL)

html = connect.text

print(html)


# 필요한 데이터 가져오기!

soup = BeautifulSoup(html, 'html.parser')

sentence = soup.select('body > div > div > div > ul > li > div > p')

print(sentence)
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# 	<meta charset="utf-8">
# 	<meta http-equiv="X-UA-Compatible" content="IE=edge">
# 	<title>네이버 영화</title>
#
#
#
#
#
#
#
# 		<link rel="shortcut icon" href="https://ssl.pstatic.net/static/m/movie/icons/naver_movie_favicon.ico" type="image/x-icon">
#
#
#
#
# <link rel="stylesheet" type="text/css" href="/css/common.css?20210728101216" />
#
# <link rel="stylesheet" type="text/css" href="/css/movie_tablet.css?20210728101216" />
# <link rel="stylesheet" type="text/css" href="/css/movie_end.css?20210728101216" />
#
#
#
#
# <script type="text/javascript" src="/js/deploy/movie.all.js?20210728101216"></script>
#
#
#
# </head>
# <body>
# 	<!-- content -->
# <input type="hidden" name="movieCode" id="movieCode" value="76460"/>
# <input type="hidden" name="onlyActualPointYn" id="onlyActualPointYn" value="N"/>
# <input type="hidden" name="includeSpoilerYn" id="includeSpoilerYn" value="N"/>
# ...

# %%
# 원하는 문장 출력하는 함수!

def get_sentence(data): # 이런 기능을 가진 함수를 만들거에요! # 정의

  # <------- 기능 ------->
  text = str(data) # 들어온 데이터를 str=문자열 형태로 만들어 줍니다!

  start = text.find('\">') + len("\">") # 시작부분을 찾습니다!
  end = text.find("</span>") # 끝부분을 찾습니다!

  sentence = text[start:end] # 시작부분과 끝부분 사이에 있는 문장을 뽑습니다!
  
  # <-------- 결과 배출 -------> 
  return sentence # 뽑은 문장을 돌려줍니다!

print(get_sentence("[<span id=\"_filtered_ment_0\">꿀잼진짜 미친영화다 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ </span>"))
# Out:
# 꿀잼진짜 미친영화다 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ

# %%
# 함수??? y = 2x + 6 ---> f(x) = 2x + 6
# 함수 : 어떤 것을 넣었을때 안에서 처리가되고 결고가 배출되는 형식
# 프로그래밍을 할때? 함수를 만났을 경우 우리가 가져야하는 자세
# 함수 -> 얘는 무슨 기능을 가졌을까?

def f(x): # 넣은 애를 2배 해주는 기능
  y = 2*x
  return y

def g(x): # 넣은애를 제곱해주는 기능을 가졌구나
  y = x*x
  return y

print(f(3))
print(g(3))
# Out:
# 6
# 9

# %%
# 네이버 영화 평점 사이트 연결 요청 ('Real Steel')

data_array = []

for page in range(1, 20):
  # 영화 홈페이지 연결 (requests)
  URL = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.naver?code=76460&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page='+str(page)

  connect = requests.get(URL)

  html = connect.text

  # 필요한 데이터 가져오기! (Beautiful Soup4)

  soup = BeautifulSoup(html, 'html.parser')

  sentence = soup.select('body > div > div > div > ul > li > div > p')

  # 원하는 문장 출력하는 함수!

  def get_sentence(data): # 이런 기능을 가진 함수를 만들거에요! # 정의

    # <------- 기능 ------->
    text = str(data) # 들어온 데이터를 str=문자열 형태로 만들어 줍니다!
    start = text.find('\">') + len("\">") # 시작부분을 찾습니다!
    end = text.find("</span>") # 끝부분을 찾습니다!

    sentence = text[start:end] # 시작부분과 끝부분 사이에 있는 문장을 뽑습니다!
    
    # <-------- 결과 배출 -------> 
    return sentence # 뽑은 문장을 돌려줍니다!

  # 1페이지 문장 뽑기

  for i in range(len(sentence)):
    sent = get_sentence(sentence[i]).replace('\t',"")
    sent = sent.replace('\r',"")
    sent = sent.replace('\n',"")
    if(sent != "관람객"):
      data_array.append(sent)

# 출력부
print(data_array)

cnt = 1
for i in range(len(data_array)):
  print(str(cnt) + "번째 댓글 : " + data_array[i])
  cnt+=1
# Out:
# ['꿀잼진짜 미친영화다 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ ', '진짜 재밌다 ', '로봇의 탈을쓴 인간의 영화 ', '숨은명작 ', '부실한 각본이였지만 소재가 살렸다. 삽입곡들도 좋았고, 대니 엘프만이 작곡한 스코어음악들도 정말 좋더라 ', '진짜 나도 모르게 환호성지르더랔ㅋㅋ ', '요근래에 본 영화중 최고작이다 뻔한 스토리이긴 하나 몰입감 있고 감동도 있다. 소재또한 참신하다 연출또한 좋타 ', '사실 기대 안하고 봤는데 생각 이상으로 재미도 있고 감동도 있었다. ', '<span class="_unfold_ment" id="_unfold_ment8"><a data-src="방금CGV채널에서 리얼스틸봤었는데 예전에 영화관에서도보고 오늘또봤는데 진짜 로봇영화중 탑이라는생각이아깝지않습니다! 휴잭맨연기력이랑 꼬마아이 연기력이 뛰어나고 또 격투의요소에서도 재미를느꼈습니다! 리얼스틸2가 나올지는모르겠지만나왔으면좋겠네요! " href="javascript:void(0);" onclick="unfoldPointMent(this);">방금CGV채널에서 리얼스틸봤었는데 예전에 영화관에서도보고 오늘또봤는데 진짜 로봇영화중 탑이라는생각이아깝지않습니다! 휴잭맨연기력이랑 꼬마아이 연기력이 뛰어나고 또 격투의요소에서도 재미를느꼈습니다! 리얼스틸2가 나올지는...</a>', '존나잼씀~ 아 마지막에 울었네ㅜ 로봇영화여서 초딩영화인줄알았는데... 의외의 감동ㅜ ', '정말 재밌게 봤습니다 제우스랑 경기할때 눈시울 붉어짐..ㅋㅋㅋㅋ ', '퍼시픽림 + 트랜스포머 1+2+3+4 &lt; 리얼스틸 ', '이건 캐명작 대박 난그냥 좋다. 감동적. 인상적. ', '예쓰잼 도그허니잼 ', '아톰이 안죽어서 다행이다 ㅠㅜ 이것저것 다 떠나서 볼만함. ', '귀가 즐겁고 눈이 즐거웠던 영화 ㅋㅋ ost가 기억에남네.. ', '존나 유치해보였는데 유치하긴했어도 존나 꿀잼이었다. 진짜 액션신 타격감 오진다 보는내내 내가 때리는것같이 몸에 힘주고봄ㅋㅋ와대박 지젼 ', '명작이네여 ', '진짜 봐라 정말 재
# ...

# %%
print("안녕하세요 \t반갑습니다")
# Out:
# 안녕하세요 	반갑습니다
